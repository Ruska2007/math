# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.linspace(-10, 10, 121)
x2 = np.linspace(-10, 10, 121)
k1 = 1
k2 = 2
plt.plot(x1, np.cos(k1*x1), label = "cos(x)")
plt.plot(x2, np.cos(k2*x2), label = "cos(2x)")
plt.legend()
